# %%
# ============================================= [ setting ] ==========================================================
import pandas as pd  # 데이터 분석 라이브러리
import numpy as np  # 계산 라이브러리
from tqdm import tqdm  # 진행바
from sklearn.metrics import roc_auc_score  # AUC 스코어 계산
from sklearn.model_selection import KFold  # K-fold CV
from bayes_opt import BayesianOptimization  # 베이지안 최적화 라이브러리
from functools import partial  # 함수 변수 고정
import lightgbm as lgb  # LightGBM 라이브러리

# %%
# ============================================= [ pre-processing ] ==============================================

def species_converter(string):
    if string == 'T':
        return 0
    elif string == 'P':
        return 1
    elif string == 'Z':
        return 2
    else:
        raise ValueError


def data_preparation(df, answer=False):
    game_ids = df['game_id'].unique()
    events = ['Ability', 'AddToControlGroup', 'Camera', 'ControlGroup', 'GetControlGroup', 'Right Click', 'Selection',
              'SetControlGroup']
    unique_event_0, unique_event_1, delta_event = {}, {}, {}
    for event in events:
        unique_event_0['P0_' + event] = 0
        unique_event_1['P1_' + event] = 0
        delta_event['delta_' + event] = 0

    species = df.groupby(['game_id', 'player']).species.unique()
    event_count = df.groupby(['game_id', 'player']).event.value_counts()
    if answer:
        winners = df.groupby(['game_id']).winner.max()

    x_data, y_data = [], []
    for game_id in tqdm(game_ids):
        df_event_count = event_count[game_id].unstack(level=-1)
        df = pd.DataFrame(species[game_id])
        df = pd.concat([df, df_event_count], axis=1)
        df = df.fillna(0)

        df_P0_species = pd.DataFrame([species_converter(df.loc[0]['species'][0])], columns=['P0_species'])
        df_P1_species = pd.DataFrame([species_converter(df.loc[1]['species'][0])], columns=['P1_species'])
        df = df.drop(['species'], axis=1)

        df_P0_event = unique_event_0.copy()
        for column in df.columns:
            df_P0_event['P0_' + column] = df.loc[0][column]
        df_P0_event = pd.DataFrame(pd.Series(df_P0_event)).T

        df_P1_event = unique_event_1.copy()
        for column in df.columns:
            df_P1_event['P1_' + column] = df.loc[1][column]
        df_P1_event = pd.DataFrame(pd.Series(df_P1_event)).T

        df_delta_event = delta_event.copy()
        for column in df.columns:
            df_delta_event['delta_' + column] = df_P0_event['P0_' + column][0] - df_P1_event['P1_' + column][0]
        df_delta_event = pd.DataFrame(pd.Series(df_delta_event)).T

        out = pd.concat([df_P0_species, df_P0_event, df_P1_species, df_P1_event, df_delta_event], axis=1)
        out.index = [game_id]
        out.index.name = 'game_id'

        x_data.append(out)
        if answer:
            y_data.append(winners[game_id])

    x_data = pd.concat(x_data)
    y_data = np.array(y_data)

    return x_data, y_data


train = pd.read_csv('C:/Users/HSystem/Desktop/data/train.csv')
x_train, y_train = data_preparation(train, answer=True)
x_train.head()
# Out:
# 100%|██████████| 38872/38872 [05:07<00:00, 126.49it/s]
#          P0_species  P0_Ability  P0_AddToControlGroup  P0_Camera  \
# game_id
# 0                 0        34.0                   2.0      444.0
# 1                 1        77.0                   1.0      627.0
# 2                 1        69.0                   6.0      413.0
# 3                 0        82.0                   0.0      713.0
# 4                 0        57.0                   1.0      430.0
#
#          P0_ControlGroup  P0_GetControlGroup  P0_Right Click  P0_Selection  \
# game_id
# 0                    0.0                24.0            35.0          50.0
# 1                    0.0               162.0           160.0         186.0
# 2                    0.0                99.0           160.0          90.0
# 3                    0.0               132.0           276.0         180.0
# 4                    0.0               224.0           177.0          67.0
#
#          P0_SetControlGroup  P1_species  ...  P1_Selection  \
# game_id                                  ...
# 0                       3.0           0  ...          57.0
# 1                      10.0           0  ...         116.0
# 2                      14.0           2  ...         232.0
# 3                       6.0           1  ...         148.0
# 4                      10.0           2  ...         126.0
#
#          P1_SetControlGroup  delta_Ability  delta_AddToControlGroup  \
# game_id
# 0                       1.0            0.0                      2.0
# 1                       8.0           10.0                      1.0
# 2                       9.0          -16.0                      1.0
# 3                      19.0           -7.0                      0.0
# 4                       8.0           21.0                     -3.0
#
#          delta_Camera  delta_ControlGroup  delta_GetControlGroup  \
# game_id
# 0                19.0                 0.0                   21.0
# 1              -231.0                 0.0                  131.0
# 2              -312.0                -2.0                  -10.0
# 3               325.0                 0.0                 -578.0
# 4               158.0                 0.0                  125.0
#
#          delta_Right Click  delta_Selection  delta_SetControlGroup
# game_id
# 0                      7.0             -7.0                    2.0
# 1                     29.0             70.0                    2.0
# 2                    -44.0           -142.0                    5.0
# 3                      8.0             32.0                  -13.0
# 4                     71.0            -59.0                    2.0
#
# [5 rows x 26 columns]

# %%
# ========================================================== [ modeling ] ===========================================================
## + [lightGBM modeling ] ==================================
def lgb_cv(num_leaves, learning_rate, n_estimators, subsample, colsample_bytree, reg_alpha, reg_lambda,
           bagging_fraction, x_data=None, y_data=None, n_splits=5, output='score'):
    score = 0
    kf = KFold(n_splits=n_splits)
    models = []
    for train_index, valid_index in kf.split(x_data):
        x_train, y_train = x_data.iloc[train_index], y_data[train_index]
        x_valid, y_valid = x_data.iloc[valid_index], y_data[valid_index]

        model = lgb.LGBMClassifier(
            num_leaves = int(num_leaves),
            learning_rate = learning_rate,
            n_estimators = int(n_estimators),
            subsample = np.clip(subsample, 0, 1),
            colsample_bytree = np.clip(colsample_bytree, 0, 1),
            reg_alpha = reg_alpha,
            reg_lambda = reg_lambda,
            bagging_fraction = np.clip(bagging_fraction, 0, 1),
            feature_fraction = np.clip(feature_fraction, 0.5, 1)
        )

        model.fit(x_train, y_train)
        models.append(model)

        pred = model.predict_proba(x_valid)[:, 1]
        true = y_valid
        score += roc_auc_score(true, pred) / n_splits

    if output == 'score':
        return score
    if output == 'model':
        return models
    
func_fixed = partial(lgb_cv, 
                     x_data = x_train, 
                     y_data = y_train, 
                     n_splits = 5, 
                     output='score')

# %%
lgbBO = BayesianOptimization(
    func_fixed,
    {
        'num_leaves': (16, 1024),  
        'learning_rate': (0.0001, 0.1),
        'n_estimators': (16, 1024),
        'subsample': (0, 1),  
        'colsample_bytree': (0, 1), 
        'reg_alpha': (0, 10),  
        'reg_lambda': (0, 50),  
        "bagging_fraction": (0, 1)
    },
    random_state = 21  
)

lgbBO.maximize(init_points = 5, n_iter = 30) # n_iter = 30 steps
# Out:
# |   iter    |  target   | baggin... | colsam... | featur... | learni... | n_esti... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# |  1        |  0.6397   |  0.04872  |  0.2891   |  0.8605   |  0.002259 |  223.6    |  67.18    |  3.023    |  33.2     |  0.3081   |
# |  2        |  0.6446   |  0.5836   |  0.06957  |  0.9337   |  0.01341  |  195.5    |  515.9    |  8.637    |  37.95    |  0.9705   |
# |  3        |  0.6369   |  0.7593   |  0.3843   |  0.7044   |  0.07136  |  288.8    |  876.9    |  9.132    |  38.04    |  0.5167   |
# |  4        |  0.6376   |  0.1678   |  0.2987   |  0.642    |  0.03279  |  479.8    |  564.7    |  2.174    |  39.99    |  0.7267   |
# |  5        |  0.6306   |  0.8493   |  0.2675   |  0.8074   |  0.06531  |  405.9    |  429.6    |  8.102    |  30.02    |  0.8983   |
# |  6        |  0.6261   |  0.8095   |  0.3793   |  0.9564   |  0.03597  |  1.021e+0 |  1.017e+0 |  5.163    |  38.54    |  0.195    |
# |  7        |  0.6362   |  0.1713   |  0.2323   |  0.5487   |  0.000278 |  1.003e+0 |  32.79    |  5.724    |  49.74    |  0.7661   |
# |  8        |  0.6378   |  0.3563   |  0.02007  |  0.9346   |  0.03971  |  22.23    |  92.27    |  9.366    |  46.58    |  0.5416   |
# |  9        |  0.6395   |  0.6722   |  0.3008   |  0.5242   |  0.07082  |  18.31    |  982.0    |  1.422    |  43.91    |  0.5715   |
# |  10       |  0.6469   |  0.9194   |  0.9202   |  0.7869   |  0.05441  |  218.9    |  62.99    |  1.275    |  36.91    |  0.1169   |
# |  11       |  0.6495   |  0.5989   |  0.8661   |  0.9642   |  0.02478  |  485.7    |  17.54    |  5.598    |  48.09    |  0.132    |
# |  12       |  0.6416   |  0.9888   |  0.714    |  0.9501   |  0.05055  |  196.0    |  520.2    |  9.539    |  41.06    |  0.55     |
# |  13       |  0.6299   |  0.9389   |  0.05279  |  0.9226   |  0.00619  |  18.17    |  646.2    |  0.06893  |  49.37    |  0.5071   |
# |  14       |  0.6251   |  0.8109   |  0.1538   |  0.8269   |  0.0701   |  536.3    |  1.015e+0 |  3.436    |  48.75    |  0.5787   |
# |  15       |  0.6189   |  0.1494   |  0.9481   |  0.5608   |  0.09738  |  1.019e+0 |  595.0    |  2.445    |  45.73    |  0.552    |
# |  16       |  0.6467   |  0.02971  |  0.264    |  0.7393   |  0.03503  |  189.4    |  285.2    |  0.2245   |  49.47    |  0.6611   |
# |  17       |  0.6351   |  0.3713   |  0.943    |  0.8712   |  0.03374  |  478.2    |  569.6    |  2.974    |  40.8     |  0.775    |
# |  18       |  0.6322   |  0.7287   |  0.602    |  0.9753   |  0.003423 |  124.7    |  1.017e+0 |  3.884    |  2.089    |  0.1205   |
# |  19       |  0.6504   |  0.8204   |  0.4103   |  0.5618   |  0.04638  |  235.4    |  21.53    |  2.825    |  46.81    |  0.6614   |
# |  20       |  0.6387   |  0.1474   |  0.1354   |  0.9684   |  0.08623  |  774.7    |  25.26    |  0.4321   |  46.64    |  0.8482   |
# |  21       |  0.6439   |  0.8638   |  0.2408   |  0.7977   |  0.006542 |  241.7    |  616.5    |  0.5766   |  49.31    |  0.4641   |
# |  22       |  0.6495   |  0.9767   |  0.545    |  0.9587   |  0.02512  |  315.1    |  25.18    |  5.963    |  49.77    |  0.4734   |
# |  23       |  0.6451   |  0.9058   |  0.4123   |  0.815    |  0.01677  |  195.3    |  17.69    |  1.75     |  49.93    |  0.6426   |
# |  24       |  0.6436   |  0.5526   |  0.929    |  0.8948   |  0.07518  |  391.6    |  31.69    |  1.163    |  48.36    |  0.5708   |
# |  25       |  0.6465   |  0.5072   |  0.8941   |  0.7551   |  0.0554   |  174.5    |  128.6    |  9.696    |  49.61    |  0.6208   |
# |  26       |  0.6452   |  0.2635   |  0.8008   |  0.8147   |  0.01245  |  771.7    |  837.1    |  8.08     |  49.19    |  0.1876   |
# |  27       |  0.6212   |  0.9645   |  0.7027   |  0.7347   |  0.08217  |  780.8    |  824.4    |  5.375    |  0.0632   |  0.1762   |
# |  28       |  0.6468   |  0.2186   |  0.5682   |  0.6494   |  0.05139  |  78.11    |  312.8    |  8.728    |  49.96    |  0.1509   |
# |  29       |  0.6275   |  0.8135   |  0.9349   |  0.5943   |  0.07288  |  646.0    |  731.7    |  8.705    |  48.88    |  0.2742   |
# |  30       |  0.632    |  0.9349   |  0.03306  |  0.8593   |  0.0336   |  992.2    |  832.5    |  9.672    |  48.75    |  0.308    |
# |  31       |  0.6227   |  0.7452   |  0.9863   |  0.8249   |  0.06225  |  846.3    |  998.0    |  0.2534   |  49.76    |  0.1694   |
# |  32       |  0.6354   |  0.3616   |  0.03041  |  0.6163   |  0.03267  |  816.4    |  323.4    |  7.583    |  49.68    |  0.451    |
# |  33       |  0.6156   |  0.8644   |  0.0681   |  0.8022   |  0.08229  |  1.023e+0 |  217.6    |  0.3189   |  42.63    |  0.3522   |
# |  34       |  0.6409   |  0.5522   |  0.0678   |  0.6237   |  0.0725   |  187.2    |  1.017e+0 |  7.666    |  47.73    |  0.6698   |
# |  35       |  0.6367   |  0.8461   |  0.1687   |  0.8441   |  0.08206  |  19.74    |  341.2    |  0.1555   |  4.334    |  0.1794   |
# =====================================================================================================================================

# %%
params = lgbBO.max['params']
models = lgb_cv(
    params['num_leaves'],
    params['learning_rate'],
    params['n_estimators'],
    params['subsample'],
    params['colsample_bytree'],
    params['reg_alpha'],
    params['reg_lambda'],
    params["bagging_fraction"],
    x_data = x_train, y_data = y_train, n_splits = 5, output = 'model')

test = pd.read_csv('C:/Users/HSystem/Desktop/data/test.csv')
x_test, _ = data_preparation(test, answer=False)

preds = []
for model in models:
    pred = model.predict_proba(x_test)[:, 1]
    preds.append(pred)
pred = np.mean(preds, axis=0)
# Out:
# 100%|██████████| 16787/16787 [02:17<00:00, 122.03it/s]

# %%
# ========================================================== [ output ] ===========================================================
submission = pd.read_csv('C:/Users/HSystem/Desktop/data/sample_submission.csv', index_col=0)
submission['winner'] = submission['winner'] + pred
submission.to_csv('C:/Users/HSystem/Desktop/data/submission.csv')
submission.head()
# Out:
#            winner
# game_id
# 38872    0.614225
# 38873    0.501006
# 38874    0.439308
# 38875    0.302744
# 38876    0.463035

# %%
# ======================================= [ Deeplearning model ] ========================================

# %%
from keras import models 
from keras import layers

# %%
model = models.Sequential()
model.add(layers.Dense(64, input_dim = 26, activation = "relu"))
model.add(layers.Dense(64, activation = "relu"))
model.add(layers.Dense(1, activation = "sigmoid"))
model.compile(optimizer  = "adam",
             loss  = "binary_crossentropy", 
             metrics = ["accuracy"])

# %%
history = model.fit(x_train, y_train,
                   epochs = 100,
                   batch_size = 32,
                   validation_split = 0.2)
# Out:
# Train on 31097 samples, validate on 7775 samples
# Epoch 1/100
# 31097/31097 [==============================] - 1s 36us/step - loss: 2.0754 - accuracy: 0.5273 - val_loss: 1.0535 - val_accuracy: 0.5448
# Epoch 2/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 1.0502 - accuracy: 0.5397 - val_loss: 0.7712 - val_accuracy: 0.5668
# Epoch 3/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.8940 - accuracy: 0.5410 - val_loss: 0.7676 - val_accuracy: 0.5592
# Epoch 4/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.8030 - accuracy: 0.5483 - val_loss: 0.8046 - val_accuracy: 0.5554
# Epoch 5/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.7669 - accuracy: 0.5518 - val_loss: 0.7355 - val_accuracy: 0.5443
# Epoch 6/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.7501 - accuracy: 0.5507 - val_loss: 0.6997 - val_accuracy: 0.5635
# Epoch 7/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.7243 - accuracy: 0.5543 - val_loss: 0.6800 - val_accuracy: 0.5784
# Epoch 8/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.7055 - accuracy: 0.5638 - val_loss: 0.6806 - val_accuracy: 0.5797
# Epoch 9/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6967 - accuracy: 0.5632 - val_loss: 0.7505 - val_accuracy: 0.5295
# Epoch 10/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6932 - accuracy: 0.5638 - val_loss: 0.6850 - val_accuracy: 0.5732
# Epoch 11/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6825 - accuracy: 0.5714 - val_loss: 0.6834 - val_accuracy: 0.5736
# Epoch 12/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6772 - accuracy: 0.5764 - val_loss: 0.6730 - val_accuracy: 0.5805
# Epoch 13/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6723 - accuracy: 0.5793 - val_loss: 0.6762 - val_accuracy: 0.5811
# Epoch 14/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6725 - accuracy: 0.5758 - val_loss: 0.6702 - val_accuracy: 0.5810
# Epoch 15/100
# 31097/31097 [==============================] - 1s 27us/step - loss: 0.6699 - accuracy: 0.5811 - val_loss: 0.6686 - val_accuracy: 0.5871
# Epoch 16/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6698 - accuracy: 0.5789 - val_loss: 0.6742 - val_accuracy: 0.5713
# Epoch 17/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6688 - accuracy: 0.5819 - val_loss: 0.6682 - val_accuracy: 0.5784
# Epoch 18/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6683 - accuracy: 0.5790 - val_loss: 0.6689 - val_accuracy: 0.5763
# Epoch 19/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6680 - accuracy: 0.5793 - val_loss: 0.6691 - val_accuracy: 0.5713
# Epoch 20/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6672 - accuracy: 0.5797 - val_loss: 0.6713 - val_accuracy: 0.5790
# Epoch 21/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6671 - accuracy: 0.5789 - val_loss: 0.6682 - val_accuracy: 0.5864
# Epoch 22/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6667 - accuracy: 0.5859 - val_loss: 0.6740 - val_accuracy: 0.5777
# Epoch 23/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6666 - accuracy: 0.5839 - val_loss: 0.6710 - val_accuracy: 0.5878
# Epoch 24/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6659 - accuracy: 0.5827 - val_loss: 0.6673 - val_accuracy: 0.5842
# Epoch 25/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6657 - accuracy: 0.5849 - val_loss: 0.6771 - val_accuracy: 0.5781
# Epoch 26/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6645 - accuracy: 0.5882 - val_loss: 0.6681 - val_accuracy: 0.5922
# Epoch 27/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6644 - accuracy: 0.5890 - val_loss: 0.6729 - val_accuracy: 0.5860
# Epoch 28/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6650 - accuracy: 0.5902 - val_loss: 0.6712 - val_accuracy: 0.5834
# Epoch 29/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6639 - accuracy: 0.5914 - val_loss: 0.6683 - val_accuracy: 0.5952
# Epoch 30/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6640 - accuracy: 0.5867 - val_loss: 0.6775 - val_accuracy: 0.5909
# Epoch 31/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6646 - accuracy: 0.5857 - val_loss: 0.6707 - val_accuracy: 0.5909
# Epoch 32/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6638 - accuracy: 0.5866 - val_loss: 0.6710 - val_accuracy: 0.5866
# Epoch 33/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6631 - accuracy: 0.5865 - val_loss: 0.6675 - val_accuracy: 0.5864
# Epoch 34/100
# 31097/31097 [==============================] - 1s 31us/step - loss: 0.6636 - accuracy: 0.5884 - val_loss: 0.6719 - val_accuracy: 0.5893
# Epoch 35/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6633 - accuracy: 0.5898 - val_loss: 0.6716 - val_accuracy: 0.5835
# Epoch 36/100
# 31097/31097 [==============================] - 1s 31us/step - loss: 0.6620 - accuracy: 0.5915 - val_loss: 0.6694 - val_accuracy: 0.5893
# Epoch 37/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6617 - accuracy: 0.5941 - val_loss: 0.6736 - val_accuracy: 0.5866
# Epoch 38/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6630 - accuracy: 0.5895 - val_loss: 0.6681 - val_accuracy: 0.5851
# Epoch 39/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6616 - accuracy: 0.5923 - val_loss: 0.6740 - val_accuracy: 0.5759
# Epoch 40/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6613 - accuracy: 0.5925 - val_loss: 0.6747 - val_accuracy: 0.5869
# Epoch 41/100
# 31097/31097 [==============================] - 1s 27us/step - loss: 0.6627 - accuracy: 0.5932 - val_loss: 0.6702 - val_accuracy: 0.5925
# Epoch 42/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6624 - accuracy: 0.5897 - val_loss: 0.6718 - val_accuracy: 0.5961
# Epoch 43/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6610 - accuracy: 0.5915 - val_loss: 0.6711 - val_accuracy: 0.5861
# Epoch 44/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6611 - accuracy: 0.5921 - val_loss: 0.6738 - val_accuracy: 0.5888
# Epoch 45/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6613 - accuracy: 0.5906 - val_loss: 0.6732 - val_accuracy: 0.5937
# Epoch 46/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6605 - accuracy: 0.5920 - val_loss: 0.6770 - val_accuracy: 0.5792
# Epoch 47/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6604 - accuracy: 0.5891 - val_loss: 0.6767 - val_accuracy: 0.5745
# Epoch 48/100
# 31097/31097 [==============================] - 1s 31us/step - loss: 0.6596 - accuracy: 0.5930 - val_loss: 0.6899 - val_accuracy: 0.5933
# Epoch 49/100
# 31097/31097 [==============================] - 1s 31us/step - loss: 0.6596 - accuracy: 0.5956 - val_loss: 0.6800 - val_accuracy: 0.5833
# Epoch 50/100
# 31097/31097 [==============================] - 1s 33us/step - loss: 0.6598 - accuracy: 0.5916 - val_loss: 0.6871 - val_accuracy: 0.5922
# Epoch 51/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6609 - accuracy: 0.5922 - val_loss: 0.6794 - val_accuracy: 0.5862
# Epoch 52/100
# 31097/31097 [==============================] - 1s 34us/step - loss: 0.6596 - accuracy: 0.5911 - val_loss: 0.6780 - val_accuracy: 0.5905
# Epoch 53/100
# 31097/31097 [==============================] - 1s 33us/step - loss: 0.6593 - accuracy: 0.5943 - val_loss: 0.6806 - val_accuracy: 0.5954
# Epoch 54/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6592 - accuracy: 0.5941 - val_loss: 0.6760 - val_accuracy: 0.5893
# Epoch 55/100
# 31097/31097 [==============================] - 1s 41us/step - loss: 0.6580 - accuracy: 0.5951 - val_loss: 0.6849 - val_accuracy: 0.5874
# Epoch 56/100
# 31097/31097 [==============================] - 1s 34us/step - loss: 0.6585 - accuracy: 0.5958 - val_loss: 0.6796 - val_accuracy: 0.5924
# Epoch 57/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6588 - accuracy: 0.5950 - val_loss: 0.6781 - val_accuracy: 0.5832
# Epoch 58/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6580 - accuracy: 0.5945 - val_loss: 0.6918 - val_accuracy: 0.5889
# Epoch 59/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6593 - accuracy: 0.5969 - val_loss: 0.6770 - val_accuracy: 0.5913
# Epoch 60/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6582 - accuracy: 0.5958 - val_loss: 0.6800 - val_accuracy: 0.5856
# Epoch 61/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6578 - accuracy: 0.5944 - val_loss: 0.6869 - val_accuracy: 0.5862
# Epoch 62/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6577 - accuracy: 0.5955 - val_loss: 0.6774 - val_accuracy: 0.5877
# Epoch 63/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6566 - accuracy: 0.5943 - val_loss: 0.6846 - val_accuracy: 0.5826
# Epoch 64/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6573 - accuracy: 0.5945 - val_loss: 0.6807 - val_accuracy: 0.5851
# Epoch 65/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6572 - accuracy: 0.5953 - val_loss: 0.6796 - val_accuracy: 0.5900
# Epoch 66/100
# 31097/31097 [==============================] - 1s 31us/step - loss: 0.6571 - accuracy: 0.5953 - val_loss: 0.6824 - val_accuracy: 0.5886
# Epoch 67/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6570 - accuracy: 0.5948 - val_loss: 0.6849 - val_accuracy: 0.5904
# Epoch 68/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6565 - accuracy: 0.5951 - val_loss: 0.6890 - val_accuracy: 0.5934
# Epoch 69/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6564 - accuracy: 0.5953 - val_loss: 0.6882 - val_accuracy: 0.5877
# Epoch 70/100
# 31097/31097 [==============================] - 1s 31us/step - loss: 0.6567 - accuracy: 0.5951 - val_loss: 0.6865 - val_accuracy: 0.5911
# Epoch 71/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6558 - accuracy: 0.5954 - val_loss: 0.6942 - val_accuracy: 0.5932
# Epoch 72/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6567 - accuracy: 0.5988 - val_loss: 0.6965 - val_accuracy: 0.5851
# Epoch 73/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6559 - accuracy: 0.5962 - val_loss: 0.6950 - val_accuracy: 0.5884
# Epoch 74/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6558 - accuracy: 0.5955 - val_loss: 0.6841 - val_accuracy: 0.5873
# Epoch 75/100
# 31097/31097 [==============================] - 1s 31us/step - loss: 0.6552 - accuracy: 0.5959 - val_loss: 0.6999 - val_accuracy: 0.5877
# Epoch 76/100
# 31097/31097 [==============================] - 1s 31us/step - loss: 0.6550 - accuracy: 0.5963 - val_loss: 0.7149 - val_accuracy: 0.5811
# Epoch 77/100
# 31097/31097 [==============================] - 1s 32us/step - loss: 0.6566 - accuracy: 0.5941 - val_loss: 0.6967 - val_accuracy: 0.5798
# Epoch 78/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6546 - accuracy: 0.5979 - val_loss: 0.7106 - val_accuracy: 0.5856
# Epoch 79/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6559 - accuracy: 0.5932 - val_loss: 0.6948 - val_accuracy: 0.5878
# Epoch 80/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6544 - accuracy: 0.5973 - val_loss: 0.7159 - val_accuracy: 0.5934
# Epoch 81/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6558 - accuracy: 0.5980 - val_loss: 0.6939 - val_accuracy: 0.5900
# Epoch 82/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6536 - accuracy: 0.5986 - val_loss: 0.7152 - val_accuracy: 0.5871
# Epoch 83/100
# 31097/31097 [==============================] - 1s 31us/step - loss: 0.6553 - accuracy: 0.5965 - val_loss: 0.6944 - val_accuracy: 0.5946
# Epoch 84/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6536 - accuracy: 0.5975 - val_loss: 0.6983 - val_accuracy: 0.5904
# Epoch 85/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6548 - accuracy: 0.5961 - val_loss: 0.7042 - val_accuracy: 0.5927
# Epoch 86/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6539 - accuracy: 0.5989 - val_loss: 0.7252 - val_accuracy: 0.5837
# Epoch 87/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6534 - accuracy: 0.5991 - val_loss: 0.7139 - val_accuracy: 0.5874
# Epoch 88/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6540 - accuracy: 0.5977 - val_loss: 0.7188 - val_accuracy: 0.5888
# Epoch 89/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6541 - accuracy: 0.5987 - val_loss: 0.7129 - val_accuracy: 0.5910
# Epoch 90/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6537 - accuracy: 0.5985 - val_loss: 0.7043 - val_accuracy: 0.5934
# Epoch 91/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6545 - accuracy: 0.5974 - val_loss: 0.7008 - val_accuracy: 0.5931
# Epoch 92/100
# 31097/31097 [==============================] - 1s 30us/step - loss: 0.6535 - accuracy: 0.5996 - val_loss: 0.6956 - val_accuracy: 0.5852
# Epoch 93/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6533 - accuracy: 0.5987 - val_loss: 0.7185 - val_accuracy: 0.5855
# Epoch 94/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6529 - accuracy: 0.5977 - val_loss: 0.6992 - val_accuracy: 0.5823
# Epoch 95/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6535 - accuracy: 0.5994 - val_loss: 0.7086 - val_accuracy: 0.5846
# Epoch 96/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6542 - accuracy: 0.5989 - val_loss: 0.7314 - val_accuracy: 0.5866
# Epoch 97/100
# 31097/31097 [==============================] - 1s 28us/step - loss: 0.6528 - accuracy: 0.5990 - val_loss: 0.7314 - val_accuracy: 0.5886
# Epoch 98/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6541 - accuracy: 0.5985 - val_loss: 0.7152 - val_accuracy: 0.5896
# Epoch 99/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6518 - accuracy: 0.6004 - val_loss: 0.7082 - val_accuracy: 0.5893
# Epoch 100/100
# 31097/31097 [==============================] - 1s 29us/step - loss: 0.6517 - accuracy: 0.6000 - val_loss: 0.7245 - val_accuracy: 0.5906

# %%
print('\nAccuracy: {:.4f}'.format(model.evaluate(x_train, y_train)[1]))
# Out:
# 38872/38872 [==============================] - 0s 11us/step
#
# Accuracy: 0.6006
